-- %% [markdown]
-- ## Leitura das 5 primieras linhas de dados da Camada Gold
--
-- Essa camada está padronizada e disponivel para a área analitica fazer análise via dashboard, consultas análitcas e diversas outras formas

-- %%
SELECT *
FROM `cat-adls-br-dev`.gold.ti_salaries LIMIT 5;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- ...

-- %% [markdown]
-- ## Fim
